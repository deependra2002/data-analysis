# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/asia.csv')
df.head()
# Out:
#                        Country Name  Country Code  \
# 0                         Sri Lanka           524
# 1                          Kiribati           826
# 2          Taiwan Province of China           528
# 3  Lao People's Democratic Republic           544
# 4                           Vanuatu           846
#
#                                       Indicator Name Indicator Code Attribute  \
# 0    Consumer Prices, period average, percent change       PCPI_PCH     Value
# 1  Gross domestic product, constant prices, Natio...      NGDP_RPCH     Value
# 2    Consumer Prices, period average, percent change       PCPI_PCH     Value
# 3    Consumer Prices, period average, percent change       PCPI_PCH     Value
# 4  Gross domestic product, constant prices, Natio...      NGDP_RPCH     Value
#
#         1990       1991       1992       1993      1994  ...      2016  \
# 0  21.495251  12.185631  11.383437  11.747398  8.448071  ...  3.984576
# ...

# %%
df.drop(['Indicator Code','Attribute'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                        Country Name  Country Code  \
# 0                         Sri Lanka           524
# 1                          Kiribati           826
# 2          Taiwan Province of China           528
# 3  Lao People's Democratic Republic           544
# 4                           Vanuatu           846
#
#                                       Indicator Name       1990       1991  \
# 0    Consumer Prices, period average, percent change  21.495251  12.185631
# 1  Gross domestic product, constant prices, Natio...  -1.331060   0.133532
# 2    Consumer Prices, period average, percent change   4.129092   3.622884
# 3    Consumer Prices, period average, percent change -26.317217  13.438570
# 4  Gross domestic product, constant prices, Natio...  11.696954   3.146960
#
#         1992       1993      1994       1995       1996  ...      2016  \
# 0  11.383437  11.747398  8.448071   7.674849  15.937351  ...  3.984576
# ...

# %%
data=pd.melt(df,id_vars=['Country Name','Country Code','Indicator Name'],var_name='Year',value_name='cpi')

# %%
data
# Out:
#                           Country Name  Country Code  \
# 0                            Sri Lanka           524
# 1                             Kiribati           826
# 2             Taiwan Province of China           528
# 3     Lao People's Democratic Republic           544
# 4                              Vanuatu           846
# ...                                ...           ...
# 8671                          Thailand           578
# 8672          Taiwan Province of China           528
# 8673                       Philippines           566
# 8674  Lao People's Democratic Republic           544
# 8675   Micronesia, Federated States of           868
#
#                                          Indicator Name         Year  \
# 0       Consumer Prices, period average, percent change         1990
# 1     Gross domestic product, constant prices, Natio...         1990
# 2       Consumer Prices, period average, percent change         1990
# ...

# %%
data.isnull().sum()
# Out:
# Country Name         0
# Country Code         0
# Indicator Name       0
# Year                 0
# cpi               1099
# dtype: int64

# %%
data.sample(30)
# Out:
#                          Country Name  Country Code  \
# 739                         Sri Lanka           524
# 2123               Korea, Republic of           542
# 3920                        Sri Lanka           524
# 3333               China, P.R.: Macao           546
# 5958    Marshall Islands, Republic of           867
# 34              China, P.R.: Mainland           924
# 8029                            Samoa           862
# 1933               Korea, Republic of           542
# 8092                         Maldives           556
# 1547                           Bhutan           514
# 7684           China, P.R.: Hong Kong           532
# 6574                        Indonesia           536
# 3259               Korea, Republic of           542
# 3506  Micronesia, Federated States of           868
# 7033                         Malaysia           548
# 3851                         Thailand           578
# 1600                        Sri Lanka           524
# ...

# %%
data=data.dropna()

# %%
data.head()
# Out:
#                        Country Name  Country Code  \
# 0                         Sri Lanka           524
# 1                          Kiribati           826
# 2          Taiwan Province of China           528
# 3  Lao People's Democratic Republic           544
# 4                           Vanuatu           846
#
#                                       Indicator Name  Year        cpi
# 0    Consumer Prices, period average, percent change  1990  21.495251
# 1  Gross domestic product, constant prices, Natio...  1990  -1.331060
# 2    Consumer Prices, period average, percent change  1990   4.129092
# 3    Consumer Prices, period average, percent change  1990 -26.317217
# 4  Gross domestic product, constant prices, Natio...  1990  11.696954

# %%
data.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Year              0
# cpi               0
# dtype: int64

# %%
l=[]
country_name=data['Country Name'].unique()
for country in country_name:
    l.append(data[data['Country Name']==country])

# %%
pr_df=pd.concat(l,axis=0)

# %%
pr_df
# Out:
#             Country Name  Country Code  \
# 0              Sri Lanka           524
# 16             Sri Lanka           524
# 59             Sri Lanka           524
# 64             Sri Lanka           524
# 154            Sri Lanka           524
# ...                  ...           ...
# 8153  China, P.R.: Macao           546
# 8154  China, P.R.: Macao           546
# 8155  China, P.R.: Macao           546
# 8156  China, P.R.: Macao           546
# 8186  China, P.R.: Macao           546
#
#                                          Indicator Name  Year        cpi
# 0       Consumer Prices, period average, percent change  1990  21.495251
# 16    Gross domestic product, constant prices, Natio...  1990   6.173549
# 59       Consumer Prices, end of period, percent change  1990  19.621981
# 64                                    Unemployment rate  1990  15.897350
# 154   Balance of Payments, Current Account, Total, N...  1990  -3.851114
# ...

# %%
pr_df[pr_df['Country Name']=='Sri Lanka']
# Out:
#      Country Name  Country Code  \
# 0       Sri Lanka           524
# 16      Sri Lanka           524
# 59      Sri Lanka           524
# 64      Sri Lanka           524
# 154     Sri Lanka           524
# ...           ...           ...
# 7771    Sri Lanka           524
# 7776    Sri Lanka           524
# 7866    Sri Lanka           524
# 7869    Sri Lanka           524
# 7929    Sri Lanka           524
#
#                                          Indicator Name  Year        cpi
# 0       Consumer Prices, period average, percent change  1990  21.495251
# 16    Gross domestic product, constant prices, Natio...  1990   6.173549
# 59       Consumer Prices, end of period, percent change  1990  19.621981
# 64                                    Unemployment rate  1990  15.897350
# 154   Balance of Payments, Current Account, Total, N...  1990  -3.851114
# ...                                                 ...   ...        ...
# ...

# %%
ind=[]
ind.append(pr_df['Indicator Name'].unique())

# %%
ind
# Out:
# [array(['Consumer Prices, period average, percent change',
#         'Gross domestic product, constant prices, National Currency, percent change',
#         'Consumer Prices, end of period, percent change',
#         'Unemployment rate',
#         'Balance of Payments, Current Account, Total, Net(BPM6), percent of GDP in U.S. dollars',
#         'Gross domestic product, constant prices, purchasing power parity, per capita, percent change',
#         'General government net lending/borrowing, percent of fiscal year GDP'],
#        dtype=object)]

# %%
pr_df[(pr_df['Country Name']=='Sri Lanka') & (pr_df['Indicator Name']=='Consumer Prices, period average, percent change') ]
# Out:
#      Country Name  Country Code  \
# 0       Sri Lanka           524
# 241     Sri Lanka           524
# 482     Sri Lanka           524
# 723     Sri Lanka           524
# 964     Sri Lanka           524
# 1205    Sri Lanka           524
# 1446    Sri Lanka           524
# 1687    Sri Lanka           524
# 1928    Sri Lanka           524
# 2169    Sri Lanka           524
# 2410    Sri Lanka           524
# 2651    Sri Lanka           524
# 2892    Sri Lanka           524
# 3133    Sri Lanka           524
# 3374    Sri Lanka           524
# 3615    Sri Lanka           524
# 3856    Sri Lanka           524
# 4097    Sri Lanka           524
# 4338    Sri Lanka           524
# 4579    Sri Lanka           524
# 4820    Sri Lanka           524
# 5061    Sri Lanka           524
# 5302    Sri Lanka           524
# 5543    Sri Lanka           524
# 5784    Sri Lanka           524
# 6025    Sri Lanka           524
# 6266    Sri Lanka           524
# 6507    Sri Lanka           524
# ...

# %%
l1=[]
country_name=data['Country Name'].unique()
for country in country_name:
    l1.append(pr_df[(pr_df['Country Name']==country) & (pr_df['Indicator Name']=='Consumer Prices, period average, percent change') ])

# %%
c_p_p=pd.concat(l1,axis=0)

# %%
c_p_p
# Out:
#             Country Name  Country Code  \
# 0              Sri Lanka           524
# 241            Sri Lanka           524
# 482            Sri Lanka           524
# 723            Sri Lanka           524
# 964            Sri Lanka           524
# ...                  ...           ...
# 7187  China, P.R.: Macao           546
# 7428  China, P.R.: Macao           546
# 7669  China, P.R.: Macao           546
# 7910  China, P.R.: Macao           546
# 8151  China, P.R.: Macao           546
#
#                                        Indicator Name  Year        cpi
# 0     Consumer Prices, period average, percent change  1990  21.495251
# 241   Consumer Prices, period average, percent change  1991  12.185631
# 482   Consumer Prices, period average, percent change  1992  11.383437
# 723   Consumer Prices, period average, percent change  1993  11.747398
# 964   Consumer Prices, period average, percent change  1994   8.448071
# ...

# %%
l1=[]
country_name=data['Country Name'].unique()
ind_c=pr_df['Indicator Name'].unique()
for ind in ind_c:
    l2=[]
    for country in country_name:
        l2.append(pr_df[(pr_df['Country Name']==country) & (pr_df['Indicator Name']==ind) ])
    l1.append(l2)

# %%
l1[1]
# Out:
# [     Country Name  Country Code  \
#  16      Sri Lanka           524
#  257     Sri Lanka           524
#  498     Sri Lanka           524
#  739     Sri Lanka           524
#  980     Sri Lanka           524
#  1221    Sri Lanka           524
#  1462    Sri Lanka           524
#  1703    Sri Lanka           524
#  1944    Sri Lanka           524
#  2185    Sri Lanka           524
#  2426    Sri Lanka           524
#  2667    Sri Lanka           524
#  2908    Sri Lanka           524
#  3149    Sri Lanka           524
#  3390    Sri Lanka           524
#  3631    Sri Lanka           524
#  3872    Sri Lanka           524
#  4113    Sri Lanka           524
#  4354    Sri Lanka           524
#  4595    Sri Lanka           524
#  4836    Sri Lanka           524
#  5077    Sri Lanka           524
#  5318    Sri Lanka           524
#  5559    Sri Lanka           524
#  5800    Sri Lanka           524
#  6041    Sri Lanka           524
#  6282    Sri Lanka           524
# ...

# %%
    df1=pd.DataFrame(pd.concat(l1[0],axis=0))
    df2=pd.DataFrame(pd.concat(l1[1],axis=0))
    df3=pd.DataFrame(pd.concat(l1[2],axis=0))
    df4=pd.DataFrame(pd.concat(l1[3],axis=0))
    df5=pd.DataFrame(pd.concat(l1[4],axis=0))
    df6=pd.DataFrame(pd.concat(l1[5],axis=0))
    df7=pd.DataFrame(pd.concat(l1[6],axis=0))

# %%
df1.head()
# Out:
#     Country Name  Country Code  \
# 0      Sri Lanka           524
# 241    Sri Lanka           524
# 482    Sri Lanka           524
# 723    Sri Lanka           524
# 964    Sri Lanka           524
#
#                                       Indicator Name  Year        cpi
# 0    Consumer Prices, period average, percent change  1990  21.495251
# 241  Consumer Prices, period average, percent change  1991  12.185631
# 482  Consumer Prices, period average, percent change  1992  11.383437
# 723  Consumer Prices, period average, percent change  1993  11.747398
# 964  Consumer Prices, period average, percent change  1994   8.448071

# %%
df2.head()
# Out:
#     Country Name  Country Code  \
# 16     Sri Lanka           524
# 257    Sri Lanka           524
# 498    Sri Lanka           524
# 739    Sri Lanka           524
# 980    Sri Lanka           524
#
#                                         Indicator Name  Year        cpi
# 16   Gross domestic product, constant prices, Natio...  1990   6.173549
# 257  Gross domestic product, constant prices, Natio...  1991  10.820597
# 498  Gross domestic product, constant prices, Natio...  1992  -3.134984
# 739  Gross domestic product, constant prices, Natio...  1993   7.476541
# 980  Gross domestic product, constant prices, Natio...  1994   8.035775

# %%
df3.head()
# Out:
#      Country Name  Country Code  \
# 59      Sri Lanka           524
# 300     Sri Lanka           524
# 541     Sri Lanka           524
# 782     Sri Lanka           524
# 1023    Sri Lanka           524
#
#                                       Indicator Name  Year        cpi
# 59    Consumer Prices, end of period, percent change  1990  19.621981
# 300   Consumer Prices, end of period, percent change  1991   9.014522
# 541   Consumer Prices, end of period, percent change  1992  13.815349
# 782   Consumer Prices, end of period, percent change  1993  10.320206
# 1023  Consumer Prices, end of period, percent change  1994   4.210316

# %%
df4.head()
# Out:
#      Country Name  Country Code     Indicator Name  Year        cpi
# 64      Sri Lanka           524  Unemployment rate  1990  15.897350
# 305     Sri Lanka           524  Unemployment rate  1991  14.664852
# 546     Sri Lanka           524  Unemployment rate  1992  14.566116
# 787     Sri Lanka           524  Unemployment rate  1993  13.776525
# 1028    Sri Lanka           524  Unemployment rate  1994  13.127159

# %%
df5.head()
# Out:
#      Country Name  Country Code  \
# 154     Sri Lanka           524
# 395     Sri Lanka           524
# 636     Sri Lanka           524
# 877     Sri Lanka           524
# 1118    Sri Lanka           524
#
#                                          Indicator Name  Year       cpi
# 154   Balance of Payments, Current Account, Total, N...  1990 -3.851114
# 395   Balance of Payments, Current Account, Total, N...  1991 -5.785810
# 636   Balance of Payments, Current Account, Total, N...  1992 -4.798067
# 877   Balance of Payments, Current Account, Total, N...  1993 -4.940644
# 1118  Balance of Payments, Current Account, Total, N...  1994 -6.884538

# %%
df6.head()
# Out:
#      Country Name  Country Code  \
# 157     Sri Lanka           524
# 398     Sri Lanka           524
# 639     Sri Lanka           524
# 880     Sri Lanka           524
# 1121    Sri Lanka           524
#
#                                          Indicator Name  Year       cpi
# 157   Gross domestic product, constant prices, purch...  1990  5.105287
# 398   Gross domestic product, constant prices, purch...  1991  9.493694
# 639   Gross domestic product, constant prices, purch...  1992 -4.233212
# 880   Gross domestic product, constant prices, purch...  1993  6.349301
# 1121  Gross domestic product, constant prices, purch...  1994  7.022872

# %%
df7.head()
# Out:
#      Country Name  Country Code  \
# 217     Sri Lanka           524
# 458     Sri Lanka           524
# 699     Sri Lanka           524
# 940     Sri Lanka           524
# 1181    Sri Lanka           524
#
#                                          Indicator Name  Year       cpi
# 217   General government net lending/borrowing, perc...  1990 -6.388580
# 458   General government net lending/borrowing, perc...  1991 -7.972538
# 699   General government net lending/borrowing, perc...  1992 -4.951440
# 940   General government net lending/borrowing, perc...  1993 -5.774541
# 1181  General government net lending/borrowing, perc...  1994 -7.405553

# %%
pr_df.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\pr_df.csv')

# %%
df1.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df1.csv')
df2.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df2.csv')
df3.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df3.csv')
df4.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df4.csv')
df5.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df5.csv')
df6.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df6.csv')
df7.to_csv(r'C:\Users\91840\Desktop\jypter\data\asia\df7.csv')
